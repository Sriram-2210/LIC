# %%
# uv run python -m ipykernel install --user --name "LIC"

# %%
from src.DocumentGeneratorBudget import BudgetDocGenerator

generator = BudgetDocGenerator("budget.xlsx")
documents = generator.generate_documents()
